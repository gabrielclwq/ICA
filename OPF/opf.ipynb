# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opfython.math.general as g
import opfython.stream.loader as l
import opfython.stream.parser as p
import opfython.stream.splitter as s
from opfython.models import KNNSupervisedOPF

# %%
# Load data:

data = pd.read_csv("bodyfat.csv")
print(data.head())

# Preprocessing:

predict = 'BodyFat'

Y = data[predict]
X = data.drop(columns=[predict])
Xlabels = X.columns

Y = Y.transform(lambda x: 1 if x <= 5 else (2 if x>5 and x<=14 else (3 if x>14 and x<16 else(4 if x>=16 and x<25 else 5))))

print(f'Target Class:\n{Y.head()}')
print(f'Feature Class:\n{X.head()}')

Y = Y.to_numpy()
X = X.to_numpy()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7
# Target Class:
# 0    2
# 1    2
# 2    5
# 3    2
# 4    5
# Name: BodyFat, dtype: int64
# Feature Class:
#    Density  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  \
# 0   1.0708   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3
# 1   1.0853   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3
# 2   1.0414   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9
# 3   1.0751   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3
# 4   1.0340   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2
#
#    Ankle  Biceps  Forearm  Wrist
# 0   21.9    32.0     27.4   17.1
# 1   23.4    30.5     28.9   18.2
# 2   24.0    28.8     25.2   16.6
# 3   22.8    32.4     29.4   18.2
# 4   24.0    32.2     27.7   17.7

# %%
# Splitting data into training and testing sets
X_train, X_test, Y_train, Y_test = s.split(
    X, Y, percentage=0.8, random_state=1)

# Splitting data into training and validation sets
X_train, X_val, Y_train, Y_val = s.split(
    X_train, Y_train, percentage=0.25, random_state=1)

# Creates an KNNSupervisedOPF instance
opf = KNNSupervisedOPF(max_k=10, distance='log_squared_euclidean', pre_computed_distance=None)

# Fits training data into the classifier
opf.fit(X_train, Y_train, X_val, Y_val)

# Predicts new data
preds = opf.predict(X_test)

# Calculating accuracy
acc = g.opf_accuracy(Y_test, preds)

print(f'Accuracy: {acc}')
# Out:
# 2022-04-19 14:54:15,319 - opfython.stream.splitter — INFO — Splitting data ...
# 2022-04-19 14:54:15,320 - opfython.stream.splitter — DEBUG — X_1: (201, 14) | X_2: (51, 14) | Y_1: (201,) | Y_2: (51,).
# 2022-04-19 14:54:15,322 - opfython.stream.splitter — INFO — Data splitted.
# 2022-04-19 14:54:15,323 - opfython.stream.splitter — INFO — Splitting data ...
# 2022-04-19 14:54:15,325 - opfython.stream.splitter — DEBUG — X_1: (50, 14) | X_2: (151, 14) | Y_1: (50,) | Y_2: (151,).
# 2022-04-19 14:54:15,326 - opfython.stream.splitter — INFO — Data splitted.
# 2022-04-19 14:54:15,330 - opfython.models.knn_supervised — INFO — Overriding class: OPF -> KNNSupervisedOPF.
# 2022-04-19 14:54:15,332 - opfython.core.opf — INFO — Creating class: OPF.
# 2022-04-19 14:54:15,333 - opfython.core.opf — DEBUG — Distance: log_squared_euclidean | Pre-computed distance: False.
# 2022-04-19 14:54:15,335 - opfython.core.opf — INFO — Class created.
# 2022-04-19 14:54:15,336 - opfython.models.knn_supervised — INFO — Class overrided.
# 2022-04-19 14:54:15,338 - opfython.models.knn_supervised — INFO — Fitting classifier ...
# 2022-04-19 14:54:15,339 - opfython.models.knn_supervised — INFO — Learning best `k` value ...
# 2022-04-19 14:54:15,360 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:15,408 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:15,410 - opfython.models.knn_supervised — INFO — Prediction time: 0.04297637939453125 seconds.
# 2022-04-19 14:54:15,414 - opfython.models.knn_supervised — INFO — Accuracy over k = 1: 0.6518444262376102
# 2022-04-19 14:54:15,447 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:15,537 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:15,540 - opfython.models.knn_supervised — INFO — Prediction time: 0.08894801139831543 seconds.
# 2022-04-19 14:54:15,548 - opfython.models.knn_supervised — INFO — Accuracy over k = 2: 0.6028299501839498
# 2022-04-19 14:54:15,597 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:15,710 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:15,717 - opfython.models.knn_supervised — INFO — Prediction time: 0.10993599891662598 seconds.
# 2022-04-19 14:54:15,719 - opfython.models.knn_supervised — INFO — Accuracy over k = 3: 0.5838438086380087
# 2022-04-19 14:54:15,759 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:15,882 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:15,884 - opfython.models.knn_supervised — INFO — Prediction time: 0.11693429946899414 seconds.
# 2022-04-19 14:54:15,886 - opfython.models.knn_supervised — INFO — Accuracy over k = 4: 0.5842120785337617
# 2022-04-19 14:54:15,917 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:16,043 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:16,048 - opfython.models.knn_supervised — INFO — Prediction time: 0.12392783164978027 seconds.
# 2022-04-19 14:54:16,051 - opfython.models.knn_supervised — INFO — Accuracy over k = 5: 0.5910167121353236
# 2022-04-19 14:54:16,105 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:16,219 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:16,220 - opfython.models.knn_supervised — INFO — Prediction time: 0.11193394660949707 seconds.
# 2022-04-19 14:54:16,222 - opfython.models.knn_supervised — INFO — Accuracy over k = 6: 0.5833333333333333
# 2022-04-19 14:54:16,253 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:16,373 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:16,374 - opfython.models.knn_supervised — INFO — Prediction time: 0.11893057823181152 seconds.
# 2022-04-19 14:54:16,377 - opfython.models.knn_supervised — INFO — Accuracy over k = 7: 0.5833333333333333
# 2022-04-19 14:54:16,453 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:16,590 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:16,591 - opfython.models.knn_supervised — INFO — Prediction time: 0.13492202758789062 seconds.
# 2022-04-19 14:54:16,593 - opfython.models.knn_supervised — INFO — Accuracy over k = 8: 0.5833333333333333
# 2022-04-19 14:54:16,652 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:16,785 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:16,786 - opfython.models.knn_supervised — INFO — Prediction time: 0.1319258213043213 seconds.
# 2022-04-19 14:54:16,788 - opfython.models.knn_supervised — INFO — Accuracy over k = 9: 0.5833333333333333
# 2022-04-19 14:54:16,859 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:16,965 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:16,966 - opfython.models.knn_supervised — INFO — Prediction time: 0.10494017601013184 seconds.
# 2022-04-19 14:54:16,968 - opfython.models.knn_supervised — INFO — Accuracy over k = 10: 0.5833333333333333
# 2022-04-19 14:54:16,986 - opfython.models.knn_supervised — INFO — Classifier has been fitted with k = 1.
# 2022-04-19 14:54:16,987 - opfython.models.knn_supervised — INFO — Training time: 1.64605712890625 seconds.
# 2022-04-19 14:54:16,990 - opfython.models.knn_supervised — INFO — Predicting data ...
# 2022-04-19 14:54:17,014 - opfython.models.knn_supervised — INFO — Data has been predicted.
# 2022-04-19 14:54:17,018 - opfython.models.knn_supervised — INFO — Prediction time: 0.020997285842895508 seconds.
# Accuracy: 0.6794977538011593
